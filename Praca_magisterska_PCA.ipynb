# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport
# !pip install scikit-learn

# %%
df = pd.read_csv("/Users/wiktoriapabis/Desktop/water_dataX.csv", encoding='latin1')

# %%
profile = ProfileReport(df,title="Water Quality Profile")

# %%
# profile.to_notebook_iframe()

# %%
df.info()
# w zbiorze danych wszystko jest typu obejct, ponieważ występują wartości NAN, razem z cyframi, oprócz "Year", który jest typu int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   object
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (µmhos/cm)           1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
# ...

# %%
df.shape
# Out:
# (1991, 12)

# %%
df.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (µmhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                     203           NAN
# 1          GOA  29.8         5.7  7.2                     189             2
# 2          GOA  29.5         6.3  6.9                     179           1.7
# 3          GOA  29.7         5.8  6.9                      64           3.8
# 4          GOA  29.5         5.8  7.3                      83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# ...

# %%
df.tail()
# Out:
#      STATION CODE                                          LOCATIONS STATE  \
# 1986         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU   NAN
# 1987         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...   NAN
# 1988         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA   NAN
# 1989         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA   NAN
# 1990         1726   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA   NAN
#
#      Temp D.O. (mg/l)   PH CONDUCTIVITY (µmhos/cm) B.O.D. (mg/l)  \
# 1986  NAN         7.9  738                     7.2           2.7
# 1987   29         7.5  585                     6.3           2.6
# 1988   28         7.6   98                     6.2           1.2
# 1989   28         7.7   91                     6.5           1.3
# 1990   29         7.6  110                     5.7           1.1
#
#      NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# ...

# %%
df.describe()
# Out:
#               year
# count  1991.000000
# mean   2010.038172
# std       3.057333
# min    2003.000000
# 25%    2008.000000
# 50%    2011.000000
# 75%    2013.000000
# max    2014.000000

# %%
df.dtypes
# Out:
# STATION CODE                        object
# LOCATIONS                           object
# STATE                               object
# Temp                                object
# D.O. (mg/l)                         object
# PH                                  object
# CONDUCTIVITY (µmhos/cm)             object
# B.O.D. (mg/l)                       object
# NITRATENAN N+ NITRITENANN (mg/l)    object
# FECAL COLIFORM (MPN/100ml)          object
# TOTAL COLIFORM (MPN/100ml)Mean      object
# year                                 int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# STATION CODE                        0
# LOCATIONS                           0
# STATE                               0
# Temp                                0
# D.O. (mg/l)                         0
# PH                                  0
# CONDUCTIVITY (µmhos/cm)             0
# B.O.D. (mg/l)                       0
# NITRATENAN N+ NITRITENANN (mg/l)    0
# FECAL COLIFORM (MPN/100ml)          0
# TOTAL COLIFORM (MPN/100ml)Mean      0
# year                                0
# dtype: int64

# %%
print(df.loc[665])
# Out:
# STATION CODE                                                  1685
# LOCATIONS                           ARASALAR RIVER KARAIKAL REGION
# STATE                                                  PONDICHERRY
# Temp                                                            31
# D.O. (mg/l)                                                    6.8
# PH                                                             7.8
# CONDUCTIVITY (µmhos/cm)                                        505
# B.O.D. (mg/l)                                                  2.1
# NITRATENAN N+ NITRITENANN (mg/l)                              0.02
# FECAL COLIFORM (MPN/100ml)
# TOTAL COLIFORM (MPN/100ml)Mean
# year                                                          2012
# Name: 665, dtype: object

# %%
df.replace("NAN", np.nan, inplace=True)
df.isna().sum()
# Out:
# STATION CODE                        122
# LOCATIONS                           184
# STATE                               761
# Temp                                 88
# D.O. (mg/l)                          31
# PH                                    8
# CONDUCTIVITY (µmhos/cm)              25
# B.O.D. (mg/l)                        40
# NITRATENAN N+ NITRITENANN (mg/l)    220
# FECAL COLIFORM (MPN/100ml)          303
# TOTAL COLIFORM (MPN/100ml)Mean      121
# year                                  0
# dtype: int64

# %%
print(df.loc[665])
# Out:
# STATION CODE                                                  1685
# LOCATIONS                           ARASALAR RIVER KARAIKAL REGION
# STATE                                                  PONDICHERRY
# Temp                                                            31
# D.O. (mg/l)                                                    6.8
# PH                                                             7.8
# CONDUCTIVITY (µmhos/cm)                                        505
# B.O.D. (mg/l)                                                  2.1
# NITRATENAN N+ NITRITENANN (mg/l)                              0.02
# FECAL COLIFORM (MPN/100ml)
# TOTAL COLIFORM (MPN/100ml)Mean
# year                                                          2012
# Name: 665, dtype: object

# %%
df.tail()
# Out:
#      STATION CODE                                          LOCATIONS STATE  \
# 1986         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU   NaN
# 1987         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...   NaN
# 1988         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA   NaN
# 1989         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA   NaN
# 1990         1726   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA   NaN
#
#      Temp D.O. (mg/l)   PH CONDUCTIVITY (µmhos/cm) B.O.D. (mg/l)  \
# 1986  NaN         7.9  738                     7.2           2.7
# 1987   29         7.5  585                     6.3           2.6
# 1988   28         7.6   98                     6.2           1.2
# 1989   28         7.7   91                     6.5           1.3
# 1990   29         7.6  110                     5.7           1.1
#
#      NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# ...

# %%
print(df.loc[665])
# Out:
# STATION CODE                                                  1685
# LOCATIONS                           ARASALAR RIVER KARAIKAL REGION
# STATE                                                  PONDICHERRY
# Temp                                                            31
# D.O. (mg/l)                                                    6.8
# PH                                                             7.8
# CONDUCTIVITY (µmhos/cm)                                        505
# B.O.D. (mg/l)                                                  2.1
# NITRATENAN N+ NITRITENANN (mg/l)                              0.02
# FECAL COLIFORM (MPN/100ml)
# TOTAL COLIFORM (MPN/100ml)Mean
# year                                                          2012
# Name: 665, dtype: object

# %%
df[df.columns[3:11]] = df[df.columns[3:11]].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1869 non-null   object
#  1   LOCATIONS                         1807 non-null   object
#  2   STATE                             1230 non-null   object
#  3   Temp                              1899 non-null   float64
#  4   D.O. (mg/l)                       1960 non-null   float64
#  5   PH                                1983 non-null   float64
#  6   CONDUCTIVITY (µmhos/cm)           1966 non-null   float64
#  7   B.O.D. (mg/l)                     1948 non-null   float64
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1766 non-null   float64
#  9   FECAL COLIFORM (MPN/100ml)        1675 non-null   float64
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1859 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Temp  D.O. (mg/l)            PH  CONDUCTIVITY (µmhos/cm)  \
# count  1899.000000  1960.000000   1983.000000              1966.000000
# mean     26.209814     6.392637    112.090674              1786.466394
# std       3.366388     1.332938   1878.930716              5552.276223
# min      10.000000     0.000000      0.000000                 0.400000
# 25%      24.750000     5.900000      6.900000                78.000000
# 50%      27.000000     6.700000      7.300000               183.000000
# 75%      28.400000     7.200000      7.700000               592.750000
# max      35.000000    11.400000  67115.000000             65700.000000
#
#        B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l)  \
# count    1948.000000                       1766.000000
# mean        6.940049                          1.623079
# std        29.400026                          4.090481
# min         0.100000                          0.000000
# ...

# %%
df.dtypes
# Out:
# STATION CODE                         object
# LOCATIONS                            object
# STATE                                object
# Temp                                float64
# D.O. (mg/l)                         float64
# PH                                  float64
# CONDUCTIVITY (µmhos/cm)             float64
# B.O.D. (mg/l)                       float64
# NITRATENAN N+ NITRITENANN (mg/l)    float64
# FECAL COLIFORM (MPN/100ml)          float64
# TOTAL COLIFORM (MPN/100ml)Mean      float64
# year                                  int64
# dtype: object

# %%
df.tail()
# Out:
#      STATION CODE                                          LOCATIONS STATE  \
# 1986         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU   NaN
# 1987         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...   NaN
# 1988         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA   NaN
# 1989         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA   NaN
# 1990         1726   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA   NaN
#
#       Temp  D.O. (mg/l)     PH  CONDUCTIVITY (µmhos/cm)  B.O.D. (mg/l)  \
# 1986   NaN          7.9  738.0                      7.2            2.7
# 1987  29.0          7.5  585.0                      6.3            2.6
# 1988  28.0          7.6   98.0                      6.2            1.2
# 1989  28.0          7.7   91.0                      6.5            1.3
# 1990  29.0          7.6  110.0                      5.7            1.1
#
#       NITRATENAN N+ NITRITENANN (mg/l)  FECAL COLIFORM (MPN/100ml)  \
# ...

# %%
df[df.duplicated()]
# Out:
#     STATION CODE LOCATIONS STATE  Temp  D.O. (mg/l)  PH  \
# 431          NaN       NaN   NaN   NaN          NaN NaN
#
#      CONDUCTIVITY (µmhos/cm)  B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l)  \
# 431                      NaN            NaN                               NaN
#
#      FECAL COLIFORM (MPN/100ml)  TOTAL COLIFORM (MPN/100ml)Mean  year
# 431                         NaN                             NaN  2013

# %%
df = df.drop_duplicates()
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [STATION CODE, LOCATIONS, STATE, Temp, D.O. (mg/l), PH, CONDUCTIVITY (µmhos/cm), B.O.D. (mg/l), NITRATENAN N+ NITRITENANN (mg/l), FECAL COLIFORM (MPN/100ml), TOTAL COLIFORM (MPN/100ml)Mean, year]
# Index: []

# %%
nan_values = np.zeros(8)
count = 0
for index, row in df.iterrows(): 
    for column in df.columns[4:11]:
        if pd.isna(row[column]):
            count += 1
    nan_values[count] += 1
    count = 0 

formatted_nan_values = ["{:.2f}".format(value) for value in nan_values]
print(formatted_nan_values)

# Liczba brakujących wartości w wierszach zaczynając od braku kończąc na 7 brakujących wartościach
# Out:
# ['1625.00', '67.00', '229.00', '44.00', '15.00', '7.00', '0.00', '3.00']

# %%
# Zamiast wyrzucać cały pomiar w przypadku stwierdzenia nieprawidłowej pojedynczej wartości zamieniam ją na nan, 
# dając szansę wykorzystania danych w przypadku, gdy w danym wierszu ilość danych w ustalonych przeze mnie dopuszczlanych 
# zakresach mieści się w kryteriach ustalonych później do odrzucenia danego wiersza (więcej niż 2 nan)

# Zastąpienie wartości D.O. (mg/l), które są mniejsze niż 0 lub większe niż 100, wartością np.nan
df.loc[(df['D.O. (mg/l)'] < 0.6) | (df['D.O. (mg/l)'] > 100), 'D.O. (mg/l)'] = np.nan

# Zastąpienie wartości PH, które są mniejsze niż 0 lub większe niż 14, wartością np.nan
df.loc[(df['PH'] < 0) | (df['PH'] > 14), 'PH'] = np.nan

# Zastąpienie wartości CONDUCTIVITY (µmhos/cm), które są mniejsze niż 0 lub większe niż 100000, wartością np.nan
df.loc[(df['CONDUCTIVITY (µmhos/cm)'] < 11) | (df['CONDUCTIVITY (µmhos/cm)'] > 9753), 'CONDUCTIVITY (µmhos/cm)'] = np.nan

# Zastąpienie wartości B.O.D. (mg/l), które są mniejsze niż 0 lub większe niż 10000, wartością np.nan
df.loc[(df['B.O.D. (mg/l)'] < 0) | (df['B.O.D. (mg/l)'] > 88), 'B.O.D. (mg/l)'] = np.nan

# Zastąpienie wartości NITRATENAN N+ NITRITENANN (mg/l), które są mniejsze niż 0 lub większe niż 150, wartością np.nan
df.loc[(df['NITRATENAN N+ NITRITENANN (mg/l)'] < 0) | (df['NITRATENAN N+ NITRITENANN (mg/l)'] > 21), 'NITRATENAN N+ NITRITENANN (mg/l)'] = np.nan

# Zastąpienie wartości FECAL COLIFORM (MPN/100ml), które są mniejsze niż 0 lub większe niż 200000000, wartością np.nan
df.loc[(df['FECAL COLIFORM (MPN/100ml)'] < 0) | (df['FECAL COLIFORM (MPN/100ml)'] > 2350), 'FECAL COLIFORM (MPN/100ml)'] = np.nan

# Zastąpienie wartości TOTAL COLIFORM (MPN/100ml)Mean, które są mniejsze niż 0 lub większe niż 200000000, wartością np.nan
df.loc[(df['TOTAL COLIFORM (MPN/100ml)Mean'] < 0) | (df['TOTAL COLIFORM (MPN/100ml)Mean'] > 3000), 'TOTAL COLIFORM (MPN/100ml)Mean'] = np.nan

# %%
nan_values = np.zeros(8)
count = 0
for index, row in df.iterrows(): 
    for column in df.columns[4:11]:
        if pd.isna(row[column]):
            count += 1
    nan_values[count] += 1
    count = 0 

formatted_nan_values = ["{:.2f}".format(value) for value in nan_values]
print(formatted_nan_values)

# Liczba brakujących wartości w wierszach zaczynając od braku kończąc na 7 brakujących wartościach
# Out:
# ['1141.00', '236.00', '467.00', '68.00', '61.00', '13.00', '1.00', '3.00']

# %%
# do konsultacji, ja przykładowo wyrzucam przypadki, gdy brakujących danych jest powyżej 2 wartości w każdym recordzie, 
# czyli wyrzucone zostanie (przed filtracją min max pam 3,3%) obecnie 5,2% danych 

# usunięcie wierszy, w których są conajmniej 3 puste wartości, a conajmniej 5 występuje z uwzględnieniem tylko kolumn 4-10
# df_filtered = df.dropna(subset=df.columns[4:11], thresh=5).copy()
# df_filtered.reset_index(drop=True, inplace=True)

# %%
df_filtered = df.copy()
# Policzenie mediany dla kolumn 4-10
median_values = df_filtered.iloc[:, 4:11].median()
# Zastąpienie brakujących wartości medianą dla odpowiednich kolumn
df_filtered.iloc[:, 4:11] = df_filtered.iloc[:, 4:11].fillna(median_values)

# %%
df_filtered.shape
# Out:
# (1990, 12)

# %%
# do wyliczenia WQI jako etykiet mam 7 parametrów w każdym recordzie, przy czym przynajmniej 5 posiada wartość liczbową w każdym recordzie (NA TEN MOMENT NIEAKTUALNE)

# %%
# Vi to wartość parametru- próbki wody

# wartości referencyjne 
Videal = {
  'D.O. (mg/l)': 14.6,                   
  'PH': 7.0,                             
  'CONDUCTIVITY (µmhos/cm)': 0,      
  'B.O.D. (mg/l)': 0,                     
  'NITRATENAN N+ NITRITENANN (mg/l)': 0, 
  'FECAL COLIFORM (MPN/100ml)': 0,        
  'TOTAL COLIFORM (MPN/100ml)Mean': 0  
}

# wartość oczekiwana dla każdego z parametrów czystej wody 
Si = {
    'D.O. (mg/l)': 10,                   
    'PH': 8.5,                             
    'CONDUCTIVITY (µmhos/cm)': 1000,        
    'B.O.D. (mg/l)': 45,                     
    'NITRATENAN N+ NITRITENANN (mg/l)': 5,  
    'FECAL COLIFORM (MPN/100ml)': 100,        
    'TOTAL COLIFORM (MPN/100ml)Mean': 1000 
}



# waga każdego z parametrów
def calculate_wi(S_i,valid_Si):
    # stała proporcjonalności
    K = 1/sum(valid_Si.values())
    return (K/S_i) 

# skala oszacowania jakości
def calculate_qi(Vi, param):
    return 100 * (Vi - Videal.get(param)) / (Si.get(param) - Videal.get(param))

# indeks jakości wody
def calculate_wqi(row):
    sum_qi_wi = 0
    sum_wi = 0



    valid_Si = Si.copy()
    for param in ['D.O. (mg/l)', 'PH', 'CONDUCTIVITY (µmhos/cm)', 'B.O.D. (mg/l)', 'NITRATENAN N+ NITRITENANN (mg/l)', 
                  'FECAL COLIFORM (MPN/100ml)', 'TOTAL COLIFORM (MPN/100ml)Mean']:   
        if pd.isna(row[param]):
            valid_Si[param] = 0
   
    for param in ['D.O. (mg/l)', 'PH', 'CONDUCTIVITY (µmhos/cm)', 'B.O.D. (mg/l)', 'NITRATENAN N+ NITRITENANN (mg/l)', 
                  'FECAL COLIFORM (MPN/100ml)', 'TOTAL COLIFORM (MPN/100ml)Mean']:                                  
        if not pd.isna(row[param]):
            qi = calculate_qi(row[param], param)
            wi = calculate_wi(Si[param], valid_Si)
            sum_qi_wi += (qi * wi)
            sum_wi += wi
    return round(sum_qi_wi / sum_wi,2)
    
print(len(df_filtered))
df_filtered.shape

for idx, row in df_filtered.iterrows():
    if idx in df_filtered.index:
        df_filtered.loc[idx, 'WQI'] = calculate_wqi(row)
# Out:
# 1990

# %%
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)
# df_filtered

# %%
df_filtered.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp  D.O. (mg/l)   PH  CONDUCTIVITY (µmhos/cm)  \
# 0  DAMAN & DIU  30.6          6.7  7.5                    203.0
# 1          GOA  29.8          5.7  7.2                    189.0
# 2          GOA  29.5          6.3  6.9                    179.0
# 3          GOA  29.7          5.8  6.9                     64.0
# 4          GOA  29.5          5.8  7.3                     83.0
#
#    B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l)  \
# 0            1.8                               0.1
# 1            2.0                               0.2
# ...

# %%
df_filtered.tail()
# Out:
#      STATION CODE                                          LOCATIONS STATE  \
# 1986         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU   NaN
# 1987         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...   NaN
# 1988         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA   NaN
# 1989         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA   NaN
# 1990         1726   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA   NaN
#
#       Temp  D.O. (mg/l)   PH  CONDUCTIVITY (µmhos/cm)  B.O.D. (mg/l)  \
# 1986   NaN          7.9  7.3                    179.0            2.7
# 1987  29.0          7.5  7.3                    179.0            2.6
# 1988  28.0          7.6  7.3                    179.0            1.2
# 1989  28.0          7.7  7.3                    179.0            1.3
# 1990  29.0          7.6  7.3                    179.0            1.1
#
#       NITRATENAN N+ NITRITENANN (mg/l)  FECAL COLIFORM (MPN/100ml)  \
# ...

# %%
df_filtered.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8a128">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a128_level0_col0" class="col_heading level0 col0" >Temp</th>
#       <th id="T_8a128_level0_col1" class="col_heading level0 col1" >D.O. (mg/l)</th>
#       <th id="T_8a128_level0_col2" class="col_heading level0 col2" >PH</th>
#       <th id="T_8a128_level0_col3" class="col_heading level0 col3" >CONDUCTIVITY (µmhos/cm)</th>
#       <th id="T_8a128_level0_col4" class="col_heading level0 col4" >B.O.D. (mg/l)</th>
#       <th id="T_8a128_level0_col5" class="col_heading level0 col5" >NITRATENAN N+ NITRITENANN (mg/l)</th>
#       <th id="T_8a128_level0_col6" class="col_heading level0 col6" >FECAL COLIFORM (MPN/100ml)</th>
#       <th id="T_8a128_level0_col7" class="col_heading level0 col7" >TOTAL COLIFORM (MPN/100ml)Mean</th>
#       <th id="T_8a128_level0_col8" class="col_heading level0 col8" >year</th>
# ...

# %%
# Zamiana wartości ujemnych w kolumnie 12 na NaN
df_filtered.iloc[:, 12] = df_filtered.iloc[:, 12].where(df_filtered.iloc[:, 12] >= 0, other=np.nan)
# Usunięcie wierszy z NaN w kolumnie 12
df_filtered = df_filtered.dropna(subset=[df_filtered.columns[12]])
# Reset indeksu
df_filtered.reset_index(drop=True, inplace=True)

# %%
df_filtered.shape
# Out:
# (1980, 13)

# %%
df_filtered.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5bde1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bde1_level0_col0" class="col_heading level0 col0" >Temp</th>
#       <th id="T_5bde1_level0_col1" class="col_heading level0 col1" >D.O. (mg/l)</th>
#       <th id="T_5bde1_level0_col2" class="col_heading level0 col2" >PH</th>
#       <th id="T_5bde1_level0_col3" class="col_heading level0 col3" >CONDUCTIVITY (µmhos/cm)</th>
#       <th id="T_5bde1_level0_col4" class="col_heading level0 col4" >B.O.D. (mg/l)</th>
#       <th id="T_5bde1_level0_col5" class="col_heading level0 col5" >NITRATENAN N+ NITRITENANN (mg/l)</th>
#       <th id="T_5bde1_level0_col6" class="col_heading level0 col6" >FECAL COLIFORM (MPN/100ml)</th>
#       <th id="T_5bde1_level0_col7" class="col_heading level0 col7" >TOTAL COLIFORM (MPN/100ml)Mean</th>
#       <th id="T_5bde1_level0_col8" class="col_heading level0 col8" >year</th>
# ...

# %%
# Wyświetlenie indeksu i nazwy każdej kolumny
for idx, col in enumerate(df_filtered.columns):
    print(f"Indeks: {idx}, Kolumna: {col}")
# Out:
# Indeks: 0, Kolumna: STATION CODE
# Indeks: 1, Kolumna: LOCATIONS
# Indeks: 2, Kolumna: STATE
# Indeks: 3, Kolumna: Temp
# Indeks: 4, Kolumna: D.O. (mg/l)
# Indeks: 5, Kolumna: PH
# Indeks: 6, Kolumna: CONDUCTIVITY (µmhos/cm)
# Indeks: 7, Kolumna: B.O.D. (mg/l)
# Indeks: 8, Kolumna: NITRATENAN N+ NITRITENANN (mg/l)
# Indeks: 9, Kolumna: FECAL COLIFORM (MPN/100ml)
# Indeks: 10, Kolumna: TOTAL COLIFORM (MPN/100ml)Mean
# Indeks: 11, Kolumna: year
# Indeks: 12, Kolumna: WQI

# %%
df_filtered.shape
# Out:
# (1980, 13)

# %%
profile = ProfileReport(df_filtered,title="Water Quality Profile")

# %%
# profile.to_notebook_iframe()

# %%
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF
from scipy.stats import norm
# %matplotlib inline

#wycignięcie tylko kolumny temperatura
temperature = df_filtered.iloc[:, 3]

# usuniecie wszystkich NaN w celu uzyskania dystrybuanty do 100%

all_values = temperature.shape[0]
print("Liczba wszystkich wartości:", all_values)

count_nan = temperature.isna().sum()
print("Liczba wartości będcych NaN:", count_nan)

count_not_nan = temperature.notna().sum()
print("Liczba wartości niebędcych NaN:", count_not_nan)


df_filteredtemp = temperature.dropna()


all_values = df_filteredtemp.shape[0]
print("Liczba wszystkich wartości po przefiltrowaniu:", all_values)

count_nan = df_filteredtemp.isna().sum()
print("Liczba wartości będacych NaN po przefiltrowaniu:", count_nan)

count_not_nan = df_filteredtemp.notna().sum()
print("Liczba wartości niebędcych NaN po przefiltrowaniu:", count_not_nan)


# obliczenie dystrybuanty empirycznej
ecdf = ECDF(df_filteredtemp)

# dopasowanie rozkładu normalnego do danych
mean_temp = np.mean(df_filteredtemp)
std_temp = np.std(df_filteredtemp)

# generowanie teoretycznej dystrybuanty normalnej
x = np.linspace(min(df_filteredtemp), max(df_filteredtemp), 1000)
normal_cdf = norm.cdf(x, loc=mean_temp, scale=std_temp)

plt.figure(figsize=(10, 6))
plt.plot(x, normal_cdf, label="Teoretyczna dystrybuanta normalna", color="orange")
plt.step(ecdf.x, ecdf.y, label="Dystrybuanta empiryczna", color="blue", where="post")
plt.xlabel("Temperatura")
plt.ylabel("Dystrybuanta")
plt.title("Dystrybuanta empiryczna i teoretyczna rozkładu normalnego")
plt.legend()
plt.grid()
plt.show()
# Out:
# Liczba wszystkich wartości: 1980
# Liczba wartości będcych NaN: 89
# Liczba wartości niebędcych NaN: 1891
# Liczba wszystkich wartości po przefiltrowaniu: 1891
# Liczba wartości będacych NaN po przefiltrowaniu: 0
# Liczba wartości niebędcych NaN po przefiltrowaniu: 1891

# %%
#Algorytmy stosowane przez autorów pracy bazowej:
# Support vector machine (SVM)
# Random forest (RF)
# Multi-layer Perceptron (MLP)
# Logistic Regression
# XG Boost
# Decision Tree
# CatBoost
# autorzy uzupełniali brakujce dane poprzez imputacje mediana (moze sprobujemy inny sposob, np. regresja, bo istnieja rozne podejscia:
# Imputacja średnią 
# Imputacja medianą 
# Imputacja modą 
# Imputacja za pomocą regresji 
# KNN Imputation
# Imputacja z użyciem algorytmów uczenia maszynowego

# %%
# from sklearn.impute import SimpleImputer
# from sklearn.model_selection import train_test_split

# print(df_filtered.iloc[:, 4:11].isna().sum())

# # Imputacja mediana

# imputer = SimpleImputer(strategy='median')

# # Przeprowadzenie imputacji
# imputated_data = imputer.fit_transform(df_filtered.iloc[:, 4:11])

df_imputated = df_filtered.copy()
# df_imputated.iloc[:, 4:11] = imputated_data

# print(df_imputated.iloc[:, 4:11].isna().sum())

# %%
#########################################################################################################
# Random Forest Regressor - predykcja wartosci
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df_imputated.iloc[:, 4:11],df_imputated.iloc[:, 12],
                                                    random_state= 99)

# %%
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(criterion = "squared_error",
                             max_depth = 8,
                             min_samples_split = 10,
                             random_state = 5)

# %%
clf.fit(X_train, Y_train)

clf.feature_importances_ 
# podglądanie wagi cech w nauczonym modelu
# Out:
# array([0.03121419, 0.06350412, 0.00694795, 0.00633369, 0.81195582,
#        0.07880148, 0.00124275])

# %%
Y_pred = clf.predict(X_test)
#Y_pred

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(Y_test, Y_pred)
print("Sredni blad bezwzgledny (mean absolute error):", mae) 
################################################################################################################
# Out:
# Sredni blad bezwzgledny (mean absolute error): 3.7194182499105333

# %%
# Random Forest Classifier - klasyfikacja

def WQI_class(WQI):
    if WQI <25:
        return 5
    elif 26 <= WQI <= 50:
        return 4
    elif 51 <= WQI <=75:
        return 3
    elif 76 <= WQI <=100:
        return 2
    else:
        return 1
    
df_imputated['WQI Class'] = 0  

for index in range(len(df_imputated)):
    WQI_value = df_imputated.iloc[index, 12] 
    df_imputated.at[index, 'WQI Class'] = WQI_class(WQI_value)

# %%
df_imputated.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp  D.O. (mg/l)   PH  CONDUCTIVITY (µmhos/cm)  \
# 0  DAMAN & DIU  30.6          6.7  7.5                    203.0
# 1          GOA  29.8          5.7  7.2                    189.0
# 2          GOA  29.5          6.3  6.9                    179.0
# 3          GOA  29.7          5.8  6.9                     64.0
# 4          GOA  29.5          5.8  7.3                     83.0
#
#    B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l)  \
# 0            1.8                               0.1
# 1            2.0                               0.2
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['D.O. (mg/l)', 'TOTAL COLIFORM (MPN/100ml)Mean', 'CONDUCTIVITY (µmhos/cm)',
            'FECAL COLIFORM (MPN/100ml)', 'PH', 'B.O.D. (mg/l)', 'NITRATENAN N+ NITRITENANN (mg/l)']

plt.figure(figsize=(12, 8))
for i, feature in enumerate(features, 1):
    plt.subplot(3, 3, i)
    sns.scatterplot(x=df_imputated[feature], y=df_imputated['WQI Class'])
    plt.xlabel(feature)
    plt.ylabel('WQI Class')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

X = df_imputated.iloc[:, 4:11]  
y = df_imputated.iloc[:, 13]    

correlation_matrix = X.corrwith(y, method='pearson') 

plt.figure(figsize=(10, 5))
sns.barplot(x=correlation_matrix.index, y=correlation_matrix.values, palette='coolwarm')
plt.axhline(0, color='black', linewidth=0.8, linestyle='dashed')
plt.xticks(rotation=45)
plt.xlabel("Zmienna wejściowa")
plt.ylabel("Współczynnik korelacji")
plt.title("Korelacja zmiennych wejściowych z WQI Class")
plt.show()

print(correlation_matrix.sort_values(ascending=False))
# Out:
# /var/folders/1t/56p153cx4knckk845dlngv7r0000gn/T/ipykernel_23272/3149368251.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_matrix.index, y=correlation_matrix.values, palette='coolwarm')
# D.O. (mg/l)                         0.394830
# TOTAL COLIFORM (MPN/100ml)Mean     -0.092600
# CONDUCTIVITY (µmhos/cm)            -0.103064
# FECAL COLIFORM (MPN/100ml)         -0.320105
# PH                                 -0.372695
# B.O.D. (mg/l)                      -0.405949
# NITRATENAN N+ NITRITENANN (mg/l)   -0.542374
# dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

X = df_imputated.iloc[:, 4:11]  
y = df_imputated.iloc[:, 13]  

correlation_matrix = X.corrwith(y, method='spearman')  

plt.figure(figsize=(10, 5))
sns.barplot(x=correlation_matrix.index, y=correlation_matrix.values, palette='coolwarm')
plt.axhline(0, color='black', linewidth=0.8, linestyle='dashed')
plt.xticks(rotation=45)
plt.xlabel("Zmienna wejściowa")
plt.ylabel("Współczynnik korelacji")
plt.title("Korelacja zmiennych wejściowych z WQI Class")
plt.show()

print(correlation_matrix.sort_values(ascending=False))
# Out:
# /var/folders/1t/56p153cx4knckk845dlngv7r0000gn/T/ipykernel_23272/2880212862.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_matrix.index, y=correlation_matrix.values, palette='coolwarm')
# D.O. (mg/l)                         0.382185
# TOTAL COLIFORM (MPN/100ml)Mean     -0.083350
# FECAL COLIFORM (MPN/100ml)         -0.241226
# CONDUCTIVITY (µmhos/cm)            -0.330897
# B.O.D. (mg/l)                      -0.380454
# PH                                 -0.424396
# NITRATENAN N+ NITRITENANN (mg/l)   -0.512341
# dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

X = df_imputated.iloc[:, 4:11]  
y = df_imputated.iloc[:, 13]    

correlation_matrix = X.corrwith(y, method='kendall')  

plt.figure(figsize=(10, 5))
sns.barplot(x=correlation_matrix.index, y=correlation_matrix.values, palette='coolwarm')
plt.axhline(0, color='black', linewidth=0.8, linestyle='dashed')
plt.xticks(rotation=45)
plt.xlabel("Zmienna wejściowa")
plt.ylabel("Współczynnik korelacji")
plt.title("Korelacja zmiennych wejściowych z WQI Class")
plt.show()

print(correlation_matrix.sort_values(ascending=False))
# Out:
# /var/folders/1t/56p153cx4knckk845dlngv7r0000gn/T/ipykernel_23272/4107708577.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_matrix.index, y=correlation_matrix.values, palette='coolwarm')
# D.O. (mg/l)                         0.302160
# TOTAL COLIFORM (MPN/100ml)Mean     -0.063476
# FECAL COLIFORM (MPN/100ml)         -0.193495
# CONDUCTIVITY (µmhos/cm)            -0.255384
# B.O.D. (mg/l)                      -0.300281
# PH                                 -0.329856
# NITRATENAN N+ NITRITENANN (mg/l)   -0.416987
# dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

X = df_imputated.iloc[:, 4:11] 
y = df_imputated.iloc[:, 13]    

methods = ['pearson', 'spearman', 'kendall']

correlation_results = pd.DataFrame()

# Obliczanie korelacji dla każdej metody
for method in methods:
    correlation_results[method] = X.corrwith(y, method=method)

plt.figure(figsize=(10, 6))
ax = correlation_results.plot(kind='bar', width=0.8, colormap='Blues', edgecolor='gray')

plt.axhline(0, color='black', linewidth=0.8, linestyle='dashed')

plt.xticks(rotation=90)  
plt.xlabel("Zmienna wejściowa")
plt.ylabel("Współczynnik korelacji")
plt.title("Porównanie korelacji zmiennych wejściowych z WQI Class (Pearson, Spearman, Kendall)")

plt.legend(title='Metody', loc='upper right')

plt.show()

print(correlation_results)
# Out:
#                                    pearson  spearman   kendall
# D.O. (mg/l)                       0.394830  0.382185  0.302160
# PH                               -0.372695 -0.424396 -0.329856
# CONDUCTIVITY (µmhos/cm)          -0.103064 -0.330897 -0.255384
# B.O.D. (mg/l)                    -0.405949 -0.380454 -0.300281
# NITRATENAN N+ NITRITENANN (mg/l) -0.542374 -0.512341 -0.416987
# FECAL COLIFORM (MPN/100ml)       -0.320105 -0.241226 -0.193495
# TOTAL COLIFORM (MPN/100ml)Mean   -0.092600 -0.083350 -0.063476

# %%
# from sklearn.metrics import confusion_matrix
# confusion_matrix(Y_test, Y_pred)

# # |    TN- dobrze zaklasyfikowana negatywna klasa  |    FP- źle zaklasyfikowana klasa pozytywna    |
# # |    FN- źle zaklasyfikowana klasa negatywna     |    TP- dobrze zaklasyfikowana pozytywna klasa |

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

X = df_imputated.iloc[:, 4:11]  # Dane wejściowe
Y = df_imputated.iloc[:, 13]    # Etykiety

# Standaryzacja danych (PCA działa lepiej na standaryzowanych danych)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA()
pca.fit(X_scaled)

# Obliczenie wyjaśnionej wariancji
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--')
plt.xlabel('Liczba głównych składowych')
plt.ylabel('Skumulowana wariancja')
plt.title('Wykres PCA')
plt.ylim(0, 1.1)
plt.grid(True)
plt.show()

# Wyświetlenie informacji o wariancji
for i, var in enumerate(explained_variance, 1):
    print(f'Główna składowa {i}: {var:.4f}')

feature_names = df_imputated.columns[4:11]

# Macierz składowych PCA 
loadings = pca.components_

for i, component in enumerate(loadings, 1):
    print(f"\nGłówna składowa {i}:")
    for feature, loading in zip(feature_names, component):
        print(f"{feature}: {loading:.4f}")
# Out:
# Główna składowa 1: 0.2742
# Główna składowa 2: 0.2269
# Główna składowa 3: 0.1387
# Główna składowa 4: 0.1379
# Główna składowa 5: 0.0982
# Główna składowa 6: 0.0649
# Główna składowa 7: 0.0592
#
# Główna składowa 1:
# D.O. (mg/l): -0.4009
# PH: 0.1864
# CONDUCTIVITY (µmhos/cm): 0.2382
# B.O.D. (mg/l): 0.5602
# NITRATENAN N+ NITRITENANN (mg/l): 0.5028
# FECAL COLIFORM (MPN/100ml): -0.2901
# TOTAL COLIFORM (MPN/100ml)Mean: -0.3115
#
# Główna składowa 2:
# D.O. (mg/l): -0.3843
# PH: -0.2115
# CONDUCTIVITY (µmhos/cm): 0.0594
# B.O.D. (mg/l): 0.2456
# NITRATENAN N+ NITRITENANN (mg/l): 0.1834
# FECAL COLIFORM (MPN/100ml): 0.5878
# TOTAL COLIFORM (MPN/100ml)Mean: 0.6038
#
# Główna składowa 3:
# D.O. (mg/l): -0.1875
# PH: -0.3240
# CONDUCTIVITY (µmhos/cm): 0.8432
# B.O.D. (mg/l): -0.1791
# NITRATENAN N+ NITRITENANN (mg/l): -0.3170
# FECAL COLIFORM (MPN/100ml): -0.1250
# TOTAL COLIFORM (MPN/100ml)Mean: -0.0250
#
# Główna składowa 4:
# D.O. (mg/l): -0.1576
# PH: -0.8578
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
import optuna
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 500)  #zmienność liczby drzew
    max_depth = trial.suggest_int('max_depth', 5, 50)  #głębokość drzewa
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)  #minimalna liczba próbek do podziału
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)  #minimalna liczba próbek na liściu
    max_features = trial.suggest_float('max_features', 0.1, 1.0)  #procent cech używanych do podziału
    bootstrap = trial.suggest_categorical('bootstrap', [True, False])  #użycie bootstrappingu
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])  #kryterium podziału

    X = df_imputated.iloc[:, 4:11]
    Y = df_imputated.iloc[:, 13]

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    pca = PCA(n_components=7)  
    X_pca = pca.fit_transform(X)

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        bootstrap=bootstrap,
        criterion=criterion,
        random_state=42
        
    )

    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)

    score = cross_val_score(model, X_pca, Y, scoring='accuracy', cv=cv, n_jobs=-1).mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)  

print("Najlepsze parametry:", study.best_params)
print("Najlepszy wynik (accuracy):", study.best_value)
# Out:
# [I 2025-02-01 00:14:44,330] A new study created in memory with name: no-name-70dc6b03-08b1-4db2-b059-9b5a9efdee18
# [I 2025-02-01 00:14:47,710] Trial 0 finished with value: 0.813973063973064 and parameters: {'n_estimators': 269, 'max_depth': 24, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 0.2527916894443622, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.813973063973064.
# [I 2025-02-01 00:14:55,211] Trial 1 finished with value: 0.8398989898989898 and parameters: {'n_estimators': 276, 'max_depth': 12, 'min_samples_split': 19, 'min_samples_leaf': 2, 'max_features': 0.9392763410918193, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 1 with value: 0.8398989898989898.
# ...

# %%
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix
from sklearn.svm import SVC 
from sklearn.preprocessing import StandardScaler

def objective(trial):
    C = trial.suggest_loguniform('C', 1e-5, 1e5)  #regularyzacja
    kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])  #typ jądra
    degree = trial.suggest_int('degree', 2, 5)  #stopień dla jądra 'poly'
    gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])  #parametr gamma
    coef0 = trial.suggest_float('coef0', 0.0, 1.0)  #stała jądra 'poly' i 'sigmoid'
    shrinking = trial.suggest_categorical('shrinking', [True, False])  #algorytm przyspieszania
    probability = trial.suggest_categorical('probability', [True, False])  #obliczanie prawdopodobieństw
    tol = trial.suggest_float('tol', 1e-5, 1e-1)  #tolerancja na błędy
    max_iter = trial.suggest_int('max_iter', -1, 10000)  #maksymalna liczba iteracji

    X = df_imputated.iloc[:, 4:11]
    Y = df_imputated.iloc[:, 13]

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    pca = PCA(n_components=7)  
    X_pca = pca.fit_transform(X)

    model = SVC(
        C=C,
        kernel=kernel,
        degree=degree,
        gamma=gamma,
        coef0=coef0,
        shrinking=shrinking,
        probability=probability,
        tol=tol,
        max_iter=max_iter,
        random_state=42
    )

    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)

    score = cross_val_score(model, X_pca, Y, scoring='accuracy', cv=cv, n_jobs=-1).mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50) 

print("Najlepsze parametry:", study.best_params)
print("Najlepszy wynik (accuracy):", study.best_value)
# Out:
# [I 2025-02-01 00:12:35,082] A new study created in memory with name: no-name-4abc08ef-2cc6-4262-88d2-4dbfbc8f9026
# /var/folders/1t/56p153cx4knckk845dlngv7r0000gn/T/ipykernel_75503/886102125.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)  #regularyzacja
# [I 2025-02-01 00:12:35,397] Trial 0 finished with value: 0.8971380471380473 and parameters: {'C': 0.8516695803594805, 'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.4572189360062665, 'shrinking': True, 'probability': False, 'tol': 0.03286878109728748, 'max_iter': 4879}. Best is trial 0 with value: 0.8971380471380473.
# ...

# %%
from sklearn.neural_network import MLPClassifier

def objective(trial):
    hidden_layer_sizes = trial.suggest_categorical('hidden_layer_sizes', [(50,), (100,), (50, 50), (100, 50)])
    activation = trial.suggest_categorical('activation', ['relu', 'tanh', 'logistic'])  #funkcja aktywacji
    solver = trial.suggest_categorical('solver', ['adam', 'sgd', 'lbfgs'])  #algorytm optymalizacji
    alpha = trial.suggest_loguniform('alpha', 1e-5, 1e-1)  #regularyzacja
    batch_size = trial.suggest_categorical('batch_size', ['auto', 32, 64, 128])  #rozmiar wsadu
    learning_rate = trial.suggest_categorical('learning_rate', ['constant', 'invscaling', 'adaptive'])  #typ tempa uczenia
    learning_rate_init = trial.suggest_loguniform('learning_rate_init', 1e-5, 1e-1)  #początkowa wartość tempa uczenia
    power_t = trial.suggest_float('power_t', 0.1, 0.9)  #parametr dla 'invscaling'
    max_iter = trial.suggest_int('max_iter', 100, 10000)  #maksymalna liczba iteracji
    shuffle = trial.suggest_categorical('shuffle', [True, False])  #losowanie danych
    tol = trial.suggest_float('tol', 1e-5, 1e-1)  #tolerancja na błąd
    momentum = trial.suggest_float('momentum', 0.5, 0.99)  #parametr momentum dla 'sgd'
    nesterovs_momentum = trial.suggest_categorical('nesterovs_momentum', [True, False])  #użycie Nesterova
    early_stopping = trial.suggest_categorical('early_stopping', [True, False])  #wczesne zatrzymanie
    validation_fraction = trial.suggest_float('validation_fraction', 0.1, 0.3)  #udział danych do walidacji przy wczesnym zatrzymaniu
    beta_1 = trial.suggest_float('beta_1', 0.5, 0.9)  #parametr beta dla 'adam'
    beta_2 = trial.suggest_float('beta_2', 0.9, 0.999)  #parametr beta dla 'adam'
    epsilon = trial.suggest_loguniform('epsilon', 1e-8, 1e-4)  #parametr epsilon dla 'adam'
    n_iter_no_change = trial.suggest_int('n_iter_no_change', 5, 20)  #liczba iteracji bez zmiany do zatrzymania
    max_fun = trial.suggest_int('max_fun', 10000, 15000)  #maksymalna liczba wywołań funkcji w 'lbfgs'


    X = df_imputated.iloc[:, 4:11]
    Y = df_imputated.iloc[:, 13]

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    pca = PCA(n_components=7)  
    X_pca = pca.fit_transform(X)

    model = MLPClassifier(
        hidden_layer_sizes=hidden_layer_sizes,
        activation=activation,
        solver=solver,
        alpha=alpha,
        batch_size=batch_size,
        learning_rate=learning_rate,
        learning_rate_init=learning_rate_init,
        power_t=power_t,
        max_iter=max_iter,
        shuffle=shuffle,
        tol=tol,
        momentum=momentum,
        nesterovs_momentum=nesterovs_momentum,
        early_stopping=early_stopping,
        validation_fraction=validation_fraction,
        beta_1=beta_1,
        beta_2=beta_2,
        epsilon=epsilon,
        n_iter_no_change=n_iter_no_change,
        max_fun=max_fun,
        random_state=42
    )

    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)

    score = cross_val_score(model, X_pca, Y, scoring='accuracy', cv=cv, n_jobs=-1).mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)  

print("Najlepsze parametry:", study.best_params)
print("Najlepszy wynik (accuracy):", study.best_value)
# Out:
# [I 2025-02-01 00:07:42,175] A new study created in memory with name: no-name-bb6005ee-224d-4ed2-abf4-bc2e17743fef
# /opt/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /opt/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /opt/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# ...

# %%
from sklearn.linear_model import LogisticRegression

def objective(trial):
    penalty = trial.suggest_categorical('penalty', ['l2'])  #typ kary (regularyzacji)
    tol = trial.suggest_float('tol', 1e-5, 1e-1)  #tolerancja na błąd
    C = trial.suggest_loguniform('C', 1e-5, 1e5)  #parametr regularyzacji
    fit_intercept = trial.suggest_categorical('fit_intercept', [True, False])  #dopasowanie wyrazu wolnego
    intercept_scaling = trial.suggest_float('intercept_scaling', 0.1, 10.0)  #skala wyrazu wolnego
    class_weight = trial.suggest_categorical('class_weight', [None, 'balanced'])  #waga klas
    solver = trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga'])  #solver
    max_iter = trial.suggest_int('max_iter', 100, 10000)  #maksymalna liczba iteracji
    warm_start = trial.suggest_categorical('warm_start', [True, False])  #użycie wcześniejszych wyników w nowych obliczeniach
    
    X = df_imputated.iloc[:, 4:11]
    Y = df_imputated.iloc[:, 13]

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    pca = PCA(n_components=7)  
    X_pca = pca.fit_transform(X)


    model = LogisticRegression(
        penalty=penalty,
        tol=tol,
        C=C,
        fit_intercept=fit_intercept,
        intercept_scaling=intercept_scaling,
        class_weight=class_weight,
        solver=solver,
        max_iter=max_iter,
        warm_start=warm_start,
        random_state=42
    )

    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)

    score = cross_val_score(model, X_pca, Y, scoring='accuracy', cv=cv, n_jobs=-1).mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50) 

print("Najlepsze parametry:", study.best_params)
print("Najlepszy wynik (accuracy):", study.best_value)
# Out:
# [I 2025-02-01 00:09:23,910] A new study created in memory with name: no-name-0222a5ad-cb13-41e9-afdd-f42b53ff1fe1
# /var/folders/1t/56p153cx4knckk845dlngv7r0000gn/T/ipykernel_75503/1549835569.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)  #parametr regularyzacji
# [I 2025-02-01 00:09:24,097] Trial 0 finished with value: 0.49242424242424243 and parameters: {'penalty': 'l2', 'tol': 0.031171181531025594, 'C': 0.0001937386099103394, 'fit_intercept': False, 'intercept_scaling': 6.541713825857706, 'class_weight': 'balanced', 'solver': 'liblinear', 'max_iter': 871, 'warm_start': False}. Best is trial 0 with value: 0.49242424242424243.
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

def objective(trial):
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])  #kryterium podziału
    splitter = trial.suggest_categorical('splitter', ['best', 'random'])  #strategia podziału
    max_depth = trial.suggest_int('max_depth', 1, 50, step=1)  #maksymalna głębokość drzewa
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)  #minimalna liczba próbek do podziału
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)  #minimalna liczba próbek w liściu
    min_weight_fraction_leaf = trial.suggest_float('min_weight_fraction_leaf', 0.0, 0.5)  #minimalna waga próbek w liściu
    max_features = trial.suggest_categorical('max_features', [None, 'sqrt', 'log2'])  #maksymalna liczba cech do podziału
    class_weight = trial.suggest_categorical('class_weight', [None, 'balanced'])  #wagi klas
    ccp_alpha = trial.suggest_float('ccp_alpha', 0.0, 0.1)  #wartość przycinania drzewa
    
    X = df_imputated.iloc[:, 4:11]
    Y = df_imputated.iloc[:, 13]

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    pca = PCA(n_components=7)  
    X_pca = pca.fit_transform(X)

    model = DecisionTreeClassifier(
        criterion=criterion,
        splitter=splitter,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        min_weight_fraction_leaf=min_weight_fraction_leaf,
        max_features=max_features,
        class_weight=class_weight,
        ccp_alpha=ccp_alpha,
        random_state=42
    )

    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)

    score = cross_val_score(model, X_pca, Y, scoring='accuracy', cv=cv, n_jobs=-1).mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000) 

print("Najlepsze parametry:", study.best_params)
print("Najlepszy wynik (accuracy):", study.best_value)
# Out:
# [I 2025-02-01 00:10:12,827] A new study created in memory with name: no-name-8c5ae091-a658-46d0-809c-69233324cead
# [I 2025-02-01 00:10:13,049] Trial 0 finished with value: 0.11936026936026937 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 1, 'min_samples_split': 3, 'min_samples_leaf': 16, 'min_weight_fraction_leaf': 0.2227104858406217, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.023051758129872358}. Best is trial 0 with value: 0.11936026936026937.
# [I 2025-02-01 00:10:13,106] Trial 1 finished with value: 0.45454545454545464 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 24, 'min_samples_split': 11, 'min_samples_leaf': 15, 'min_weight_fraction_leaf': 0.27785522737671875, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.040031121149496675}. Best is trial 1 with value: 0.45454545454545464.
# ...

# %%
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold
import optuna

def objective(trial):
    iterations = trial.suggest_int('iterations', 100, 1000)  #liczba iteracji
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-4, 0.3)  #tempo uczenia
    depth = trial.suggest_int('depth', 4, 12)  #głębokość drzewa
    l2_leaf_reg = trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10.0)  # regularyzacja L2
    border_count = trial.suggest_int('border_count', 32, 255)  #liczba granic kwantyzacji
    bagging_temperature = trial.suggest_float('bagging_temperature', 0.0, 1.0)  #temperatura baggingu
    random_strength = trial.suggest_float('random_strength', 0.0, 10.0)  #siła szumu
    grow_policy = trial.suggest_categorical('grow_policy', ['SymmetricTree', 'Depthwise', 'Lossguide'])  #strategia wzrostu drzewa

    X = df_imputated.iloc[:, 4:11]
    Y = df_imputated.iloc[:, 13]  

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    pca = PCA(n_components=7)  
    X_pca = pca.fit_transform(X)

    model = CatBoostClassifier(
        iterations=iterations,
        learning_rate=learning_rate,
        depth=depth,
        l2_leaf_reg=l2_leaf_reg,
        border_count=border_count,
        bagging_temperature=bagging_temperature,
        random_strength=random_strength,
        grow_policy=grow_policy,
        verbose=0,  
        random_seed=42,
        loss_function='MultiClass'
    )
 
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)
    score = cross_val_score(model, X_pca, Y, scoring='accuracy', cv=cv, n_jobs=-1).mean()

    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50) 

print("Najlepsze parametry:", study.best_params)
print("Najlepszy wynik (accuracy):", study.best_value)
# Out:
# [I 2025-01-31 21:04:40,739] A new study created in memory with name: no-name-25951b64-2c86-4819-b799-e2f8bcd98fa7
# /var/folders/1t/56p153cx4knckk845dlngv7r0000gn/T/ipykernel_75503/3469752437.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-4, 0.3)  #tempo uczenia
# /var/folders/1t/56p153cx4knckk845dlngv7r0000gn/T/ipykernel_75503/3469752437.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   l2_leaf_reg = trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10.0)  # regularyzacja L2
# ...

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
import optuna

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 1000)  #liczba drzew
    max_depth = trial.suggest_int('max_depth', 3, 12)  #maksymalna głębokość drzewa
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3, log=True)  #tempo uczenia
    subsample = trial.suggest_float('subsample', 0.5, 1.0)  #proporcja próbkowania
    colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)  #proporcja kolumn na drzewo
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)  #minimalna waga dla liści
    gamma = trial.suggest_float('gamma', 0.0, 5.0)  #minimalne wzmocnienie podziału
    reg_alpha = trial.suggest_float('reg_alpha', 1e-5, 10.0, log=True)  #L1 regularization
    reg_lambda = trial.suggest_float('reg_lambda', 1e-5, 10.0, log=True)  #L2 regularization

    X = df_imputated.iloc[:, 4:11]
    Y = df_imputated.iloc[:, 13]

    # Dostosowanie etykiet do zakresu [0, 4]
    Y = Y - 1

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    pca = PCA(n_components=7)  
    X_pca = pca.fit_transform(X)

    model = xgb.XGBClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        min_child_weight=min_child_weight,
        gamma=gamma,
        reg_alpha=reg_alpha,
        reg_lambda=reg_lambda,
        random_state=42,
        use_label_encoder=False,
        eval_metric="mlogloss"
    )

    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)
    score = cross_val_score(model, X_pca, Y, scoring='accuracy', cv=cv, n_jobs=-1).mean()

    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100) 

print("Najlepsze parametry:", study.best_params)
print("Najlepszy wynik (accuracy):", study.best_value)
# Out:
# [I 2025-01-31 23:26:30,913] A new study created in memory with name: no-name-301d70f9-0f8e-4bdb-9985-34e89e71dafe
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [23:26:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [23:26:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [23:26:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score

X = df_imputated.iloc[:, 4:11].values
Y = df_imputated.iloc[:, 13].values

scaler = StandardScaler()
X = scaler.fit_transform(X)

label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)

clf = TabNetClassifier()

# Walidacja krzyżowa 
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)
scores = cross_val_score(clf, X, Y, scoring='accuracy', cv=cv, n_jobs=-1)

print("Wyniki dokładności (accuracy) dla każdej iteracji walidacji krzyżowej:\n", scores)
print("Średnia dokładność:", scores.mean())
print("Odchylenie standardowe dokładności:", scores.std())
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# /opt/anaconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# /opt/anaconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# /opt/anaconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:687: UserWarning: No early stopping will be performed, last training weights will be used.
#   warnings.warn(wrn_msg)
# /opt/anaconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:687: UserWarning: No early stopping will be performed, last training weights will be used.
#   warnings.warn(wrn_msg)
# ...

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
import optuna

X = df_imputated.iloc[:, 4:11].values
Y = df_imputated.iloc[:, 13].values

scaler = StandardScaler()
X = scaler.fit_transform(X)

label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)

def objective(trial):
    n_d = trial.suggest_int('n_d', 8, 64)  #rozmiar warstwy decyzyjnej
    n_a = trial.suggest_int('n_a', 8, 64)  #rozmiar warstwy uwagowej
    n_steps = trial.suggest_int('n_steps', 3, 10)  #liczba kroków w TabNet
    gamma = trial.suggest_float('gamma', 1.0, 2.0)  # współczynnik relaksacji
    lambda_sparse = trial.suggest_float('lambda_sparse', 1e-6, 1e-3, log=True)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.2, log=True) 

    model = TabNetClassifier(
        n_d=n_d, 
        n_a=n_a, 
        n_steps=n_steps, 
        gamma=gamma,
        lambda_sparse=lambda_sparse, 
        optimizer_params=dict(lr=learning_rate), 
        seed=42
    )

    # Walidacja krzyżowa
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=99)
    scores = []

    for train_idx, test_idx in cv.split(X, Y):
        X_train, X_test = X[train_idx], X[test_idx]
        Y_train, Y_test = Y[train_idx], Y[test_idx]

        model.fit(
            X_train, Y_train,
            eval_set=[(X_test, Y_test)],
            eval_name=["valid"],
            eval_metric=["accuracy"],
            patience=20,
            max_epochs=200,
            batch_size=256,
            virtual_batch_size=64,
        )

        Y_pred = model.predict(X_test)
        score = (Y_pred == Y_test).mean()
        scores.append(score)

    return np.mean(scores)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1)  

print("Najlepsze parametry:", study.best_params)
print("Najlepszy wynik (accuracy):", study.best_value)
# Out:
# [I 2025-01-08 01:09:43,580] A new study created in memory with name: no-name-ee32a940-27d4-4563-aa84-eda9e0ca58a7
# /opt/anaconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.64602 | valid_accuracy: 0.64141 |  0:00:00s
# epoch 1  | loss: 0.94857 | valid_accuracy: 0.74747 |  0:00:00s
# epoch 2  | loss: 0.76296 | valid_accuracy: 0.68687 |  0:00:00s
# epoch 3  | loss: 0.68563 | valid_accuracy: 0.77778 |  0:00:00s
# epoch 4  | loss: 0.64822 | valid_accuracy: 0.76263 |  0:00:00s
# epoch 5  | loss: 0.61461 | valid_accuracy: 0.81818 |  0:00:00s
# epoch 6  | loss: 0.61588 | valid_accuracy: 0.87879 |  0:00:00s
# epoch 7  | loss: 0.54939 | valid_accuracy: 0.83333 |  0:00:00s
# epoch 8  | loss: 0.51548 | valid_accuracy: 0.88384 |  0:00:00s
# epoch 9  | loss: 0.49634 | valid_accuracy: 0.84343 |  0:00:00s
# epoch 10 | loss: 0.49315 | valid_accuracy: 0.86869 |  0:00:00s
# ...
